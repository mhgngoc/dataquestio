# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.head(1)
# Out:
#    Rank  Major_code                  Major   Total     Men  Women  \
# 0     1        2419  PETROLEUM ENGINEERING  2339.0  2057.0  282.0
#
#   Major_category  ShareWomen  Sample_size  Employed  ...  Part_time  \
# 0    Engineering    0.120564           36      1976  ...        270
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
#
# [1 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads.shape
# Out:
# (173, 21)

# %%
recent_grads = recent_grads.dropna()
recent_grads.shape
# Out:
# (172, 21)

# %%
recent_grads.plot(x="Sample_size",y="Median",kind="scatter",title="Sample_size and Median",figsize=(5,5))
plt.show()

# %%
recent_grads.plot(x="Sample_size",y="Unemployment_rate",kind="scatter",title="Sample_size and Unemployment_rate",figsize=(5,5))
plt.show()

# %%
recent_grads.plot(x="Full_time",y="Median",kind="scatter",title="Full_time and Median",figsize=(5,5))
plt.show()

# %%
recent_grads.plot(x="ShareWomen",y="Unemployment_rate",kind="scatter",title="ShareWomen and Unemployment_rate",figsize=(5,5))
plt.show()

# %%
recent_grads.plot(x="Men",y="Median",kind="scatter",title="Men and Median",figsize=(5,5))
plt.show()

# %%
recent_grads.plot(x="Women",y="Median",kind="scatter",title="Women and Median",figsize=(5,5))
plt.show()

# %%
recent_grads["Sample_size"].hist(bins=25)
plt.show()

# %%
recent_grads["Median"].hist(bins=25)
plt.show()

# %%
recent_grads["Employed"].hist(bins=25)
plt.show()

# %%
recent_grads["Full_time"].hist(bins=25)
plt.show()

# %%
recent_grads["ShareWomen"].hist(bins=25)
plt.show()

# %%
recent_grads["Unemployment_rate"].hist(bins=25)
plt.show()

# %%
recent_grads["Men"].hist(bins=25)
plt.show()

# %%
recent_grads["Women"].hist(bins=25)
plt.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["Women","Men"]])
plt.show()

# %%
scatter_matrix(recent_grads[["Sample_size","Median"]])
plt.show()

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]])
plt.show()

# %%
sorted_median = recent_grads["Median"].sort_values()
top_ten_median = recent_grads.loc[sorted_median.tail(10).index]
last_ten_median = recent_grads.loc[sorted_median.head(10).index]
top_ten_median.plot.bar(x="Major", y="ShareWomen")
plt.show()

# %%
last_ten_median.plot.bar(x="Major", y="ShareWomen")
plt.show()

# %%
top_ten_median.plot.bar(x="Major", y="Unemployment_rate")
plt.show()

# %%
last_ten_median.plot.bar(x="Major", y="Unemployment_rate")
plt.show()
